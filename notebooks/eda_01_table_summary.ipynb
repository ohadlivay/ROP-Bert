# %% [markdown]
# # EDA 01: OMOP Table-Level Population Summary
#
# This notebook runs the read-only table-level population summary over the `mimic_omop2` OMOP Parquet export. The reusable implementation lives in `../scripts/eda_01_table_summary.py`.

# %%
from pathlib import Path

PROJECT_ROOT = Path('/Users/razimreeh/Documents/ROP-Bert')
EXPORT_DIR = Path('/Users/razimreeh/Library/CloudStorage/GoogleDrive-razi.mreeh.rm@gmail.com/My Drive/OMOP_exports/mimic_omop2')
PROJECT_ROOT, EXPORT_DIR.exists()

# %%
# %run ../scripts/eda_01_table_summary.py --export-dir "$EXPORT_DIR"

# %%
import pandas as pd

summary = pd.read_csv(PROJECT_ROOT / 'docs/eda_01_table_summary.csv')
summary
